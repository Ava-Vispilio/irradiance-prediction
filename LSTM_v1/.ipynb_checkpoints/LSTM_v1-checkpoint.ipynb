# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
# Load data from Excel file
data = pd.read_excel('traindata_v1.xlsx')

# Ensure 'Time' is numeric
data['Time'] = pd.to_numeric(data['Time'], errors='coerce')  # Convert strings, set invalid to NaN
data.dropna(subset=['Time'], inplace=True)  # Remove rows where 'Time' couldn't be converted

# Function to convert decimal time to HHMM format
def decimal_to_hhmm(decimal_times):
    decimal_times = np.clip(decimal_times, 0, 0.9999)  # Ensure values are valid
    hours = (decimal_times * 24).astype(int)  # Extract hours
    minutes = ((decimal_times * 24 - hours) * 60).astype(int)  # Extract minutes
    return [f"{h:02d}{m:02d}" for h, m in zip(hours, minutes)]  # Format as HHMM

# Apply conversion
data['Formatted Time'] = decimal_to_hhmm(data['Time'])

# Convert to integer format
data['Time'] = data['Formatted Time'].astype(int)

# Drop temporary column
data.drop(columns=['Formatted Time'], inplace=True)

# Check out what the formatted data looks like
data.head()
# Out:
#      Year       Date  Time  Pressure  Air Temp  Relative Humidity  Wind Speed  \
# 1  2016.0 2024-09-05     5     100.4     27.40               78.5         0.2
# 2  2016.0 2024-09-05    10     100.4     27.27               79.0         0.2
# 3  2016.0 2024-09-05    15     100.4     27.11               79.2         0.2
# 4  2016.0 2024-09-05    20     100.4     27.01               79.3         0.2
# 5  2016.0 2024-09-05    25     100.4     27.14               79.3         0.2
#
#    Wind Direction  Incoming Radiation  Rainfall
# 1           34.95               0.000       0.0
# 2           57.16               0.049       0.0
# 3           78.80               0.049       0.0
# 4           68.40               0.000       0.0
# 5           68.49               0.000       0.0

# %%
# Separate features and target variable
input_features = data[['Time', 'Pressure', 'Air Temp', 'Relative Humidity', 'Wind Speed', 'Rainfall']].values
output_variable = data['Incoming Radiation'].values.reshape(-1, 1)

# Look at what the features look like
print(input_features)
print(output_variable)
# Out:
# [[5.000e+00 1.004e+02 2.740e+01 7.850e+01 2.000e-01 0.000e+00]
#  [1.000e+01 1.004e+02 2.727e+01 7.900e+01 2.000e-01 0.000e+00]
#  [1.500e+01 1.004e+02 2.711e+01 7.920e+01 2.000e-01 0.000e+00]
#  ...
#  [2.350e+03 1.002e+02 2.660e+01 7.470e+01 2.000e-01 0.000e+00]
#  [2.355e+03 1.002e+02 2.667e+01 7.430e+01 2.000e-01 0.000e+00]
#  [2.359e+03 1.002e+02 2.670e+01 7.430e+01 2.000e-01 0.000e+00]]
# [[0.   ]
#  [0.049]
#  [0.049]
#  ...
#  [0.   ]
#  [0.049]
#  [0.049]]

# %%
# Normalize the input data to the range [0, 1]
scaler_input = MinMaxScaler()
P = scaler_input.fit_transform(input_features)

# Normalize the target variable to the range [0, 1]
scaler_output = MinMaxScaler()
T = scaler_output.fit_transform(output_variable)

# Look at what the final training data looks like
# print(P)
# print(T)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.layers import Input

# Split the data into training (first 1820 time steps) and testing (remaining time steps)
train_data = P[:1820]
train_label = T[:1820]
P_test = P[1820:]
T_test = T[1820:]

# Reshape input data to 3D format (samples, time steps, features)
train_data = train_data.reshape((train_data.shape[0], 1, train_data.shape[1]))
P_test = P_test.reshape((P_test.shape[0], 1, P_test.shape[1]))

# Define the number of features and responses
num_features = input_features.shape[1]
num_responses = 1

model = Sequential([
    Input(shape=(1, num_features)),  # Explicit Input layer
    LSTM(100),
    Dense(num_responses)
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
history = model.fit(train_data, train_label, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0637 - val_loss: 0.0328
# Epoch 2/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0455 - val_loss: 0.0352
# Epoch 3/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0360 - val_loss: 0.0386
# Epoch 4/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0401 - val_loss: 0.0405
# Epoch 5/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0394 - val_loss: 0.0555
# Epoch 6/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0372 - val_loss: 0.0478
# Epoch 7/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0370 - val_loss: 0.0579
# Epoch 8/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0397 - val_loss: 0.0545
# Epoch 9/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0338 - val_loss: 0.0596
# Epoch 10/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0350 - val_loss: 0.0630
# Epoch 11/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0362 - val_loss: 0.0731
# Epoch 12/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0357 - val_loss: 0.0555
# Epoch 13/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0352 - val_loss: 0.0651
# Epoch 14/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0337 - val_loss: 0.0827
# Epoch 15/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0328 - val_loss: 0.0761
# Epoch 16/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0354 - val_loss: 0.0767
# Epoch 17/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0341 - val_loss: 0.0692
# Epoch 18/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0318 - val_loss: 0.0804
# Epoch 19/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0305 - val_loss: 0.0661
# Epoch 20/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0325 - val_loss: 0.0719
# Epoch 21/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0345 - val_loss: 0.0702
# Epoch 22/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0315 - val_loss: 0.0688
# Epoch 23/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0326 - val_loss: 0.0857
# Epoch 24/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0310 - val_loss: 0.0757
# Epoch 25/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0298 - val_loss: 0.0642
# Epoch 26/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0326 - val_loss: 0.0767
# Epoch 27/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0302 - val_loss: 0.0693
# Epoch 28/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0283 - val_loss: 0.0582
# Epoch 29/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0310 - val_loss: 0.0636
# Epoch 30/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0280 - val_loss: 0.0551
# Epoch 31/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0282 - val_loss: 0.0621
# Epoch 32/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0257 - val_loss: 0.0565
# Epoch 33/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0270 - val_loss: 0.0675
# Epoch 34/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0276 - val_loss: 0.0681
# Epoch 35/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0267 - val_loss: 0.0548
# Epoch 36/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0294 - val_loss: 0.0620
# Epoch 37/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0247 - val_loss: 0.0591
# Epoch 38/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0258 - val_loss: 0.0493
# Epoch 39/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0245 - val_loss: 0.0642
# Epoch 40/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0266 - val_loss: 0.0706
# Epoch 41/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0249 - val_loss: 0.0618
# Epoch 42/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0257 - val_loss: 0.0616
# Epoch 43/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0265 - val_loss: 0.0572
# Epoch 44/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0261 - val_loss: 0.0542
# Epoch 45/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0251 - val_loss: 0.0555
# Epoch 46/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0250 - val_loss: 0.0503
# Epoch 47/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0247 - val_loss: 0.0506
# Epoch 48/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0275 - val_loss: 0.0534
# Epoch 49/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0242 - val_loss: 0.0527
# Epoch 50/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0233 - val_loss: 0.0561
# Epoch 51/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0219 - val_loss: 0.0521
# Epoch 52/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0226 - val_loss: 0.0457
# Epoch 53/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0206 - val_loss: 0.0431
# Epoch 54/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0270 - val_loss: 0.0500
# Epoch 55/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0223 - val_loss: 0.0526
# Epoch 56/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0225 - val_loss: 0.0525
# Epoch 57/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0259 - val_loss: 0.0514
# Epoch 58/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0268 - val_loss: 0.0495
# Epoch 59/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0218 - val_loss: 0.0600
# Epoch 60/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0247 - val_loss: 0.0502
# Epoch 61/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0242 - val_loss: 0.0484
# Epoch 62/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0230 - val_loss: 0.0482
# Epoch 63/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0249 - val_loss: 0.0489
# Epoch 64/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0243 - val_loss: 0.0439
# Epoch 65/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0244 - val_loss: 0.0451
# Epoch 66/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0254 - val_loss: 0.0484
# Epoch 67/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0235 - val_loss: 0.0442
# Epoch 68/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0255 - val_loss: 0.0465
# Epoch 69/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0218 - val_loss: 0.0466
# Epoch 70/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0223 - val_loss: 0.0396
# Epoch 71/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0220 - val_loss: 0.0475
# Epoch 72/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0248 - val_loss: 0.0484
# Epoch 73/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0241 - val_loss: 0.0480
# Epoch 74/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0245 - val_loss: 0.0479
# Epoch 75/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0241 - val_loss: 0.0489
# Epoch 76/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0236 - val_loss: 0.0394
# Epoch 77/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0249 - val_loss: 0.0454
# Epoch 78/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0207 - val_loss: 0.0444
# Epoch 79/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0267 - val_loss: 0.0411
# Epoch 80/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0243 - val_loss: 0.0462
# Epoch 81/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0223 - val_loss: 0.0479
# Epoch 82/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0243 - val_loss: 0.0430
# Epoch 83/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0244 - val_loss: 0.0473
# Epoch 84/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0227 - val_loss: 0.0457
# Epoch 85/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0246 - val_loss: 0.0419
# Epoch 86/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0215 - val_loss: 0.0399
# Epoch 87/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0235 - val_loss: 0.0435
# Epoch 88/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0260 - val_loss: 0.0417
# Epoch 89/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0252 - val_loss: 0.0403
# Epoch 90/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0254 - val_loss: 0.0482
# Epoch 91/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0243 - val_loss: 0.0406
# Epoch 92/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0230 - val_loss: 0.0397
# Epoch 93/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0265 - val_loss: 0.0434
# Epoch 94/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0230 - val_loss: 0.0446
# Epoch 95/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0228 - val_loss: 0.0461
# Epoch 96/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0241 - val_loss: 0.0452
# Epoch 97/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0265 - val_loss: 0.0410
# Epoch 98/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0245 - val_loss: 0.0409
# Epoch 99/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0242 - val_loss: 0.0435
# Epoch 100/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0234 - val_loss: 0.0421

# %%
# Make predictions on the test set
predictions = model.predict(P_test)

# Reverse map the normalized predictions and targets to their original scales
YPred = scaler_output.inverse_transform(predictions)
YTest = scaler_output.inverse_transform(T_test)

# Calculate RMSE (Root Mean Squared Error)
rmse = np.sqrt(np.mean((YPred - YTest)**2))

# Plot the actual and predicted values
plt.figure()
plt.plot(YTest, label='Actual')
plt.plot(YPred, 'r', label='Predicted')
plt.legend(['Actual', 'Predicted'])
plt.title(f'RMSE: {rmse}')
plt.xlabel('Time Steps')
plt.ylabel('Target Variable')

# Display RMSE value
print(f'Root Mean Squared Error (RMSE): {rmse}')

# Plot training and validation loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(['Train Loss', 'Validation Loss'])
plt.title('Model Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Root Mean Squared Error (RMSE): 208.2542928314727
# Text(0, 0.5, 'Loss')
